# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold

from semi_supervised_autoencoder_ssae import ssae
import tensorflow as tf
from keras import models
import keras
import os
import warnings

from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore", category=UserWarning, module="keras")

name_df = 'df_completo_filtrato_tesi'
result_path = os.path.join('./results', name_df)
result_path = os.path.join(result_path, 'binary')
result_path = os.path.join(result_path, 'with_metadata')

tf.config.run_functions_eagerly(True)
tf.data.experimental.enable_debug_mode()
np.random.seed(0)
tf.random.set_seed(800)
keras.utils.set_random_seed(800)

# %%
df = pd.read_csv(f'data/{name_df}.csv', encoding='utf-8')
df
# Out:
#          SampleID   Lysinibacillus   Fusobacterium   Bacteroides   Prevotella  \
# 0       ERR475500        10.226518       -1.030177      5.755034     0.510268
# 1    Cancer7-2537        -0.586193       10.592280      7.821557     1.259633
# 2       ERR475501         2.075989       -0.632061     10.370550     1.601531
# 3       ERR475507        -1.191359       -1.191359      8.804981     9.638508
# 4       ERR475506        -0.766400       -0.766400      5.069385     3.252982
# ..            ...              ...             ...           ...          ...
# 703    SRR2143774        -0.189901       -0.189901      4.986249    -0.189901
# 704    SRR2143541        -0.213003       -0.213003      5.827251    -0.213003
# 705    SRR2143550        -0.147902       -0.147902      5.889173     5.721395
# 706    SRR2143990        -0.323407       -0.323407      4.330554    -0.323407
# 707    SRR2143628        -0.180056       -0.180056      5.147820    -0.180056
#
#       Sphingomonas   Blautia   Faecalibacterium  \
# 0         6.975524  4.476509           3.372469
# 1        -0.586193  8.361916           2.004074
# 2         8.780430  6.639179           5.296641
# 3         7.414333  6.018967           8.587208
# 4        10.018656  9.904569           3.972718
# ..             ...       ...                ...
# 703      -0.189901  5.621240           4.034496
# 704      -0.213003  4.898984           3.658198
# 705      -0.147902  4.246547           4.238283
# 706      -0.323407  4.889716           1.573713
# 707      -0.180056  4.990428           2.653157
#
#       [Eubacterium]_coprostanoligenes_group   Akkermansia  ...     Study  \
# 0                                  5.962226      8.748899  ...    Zeller
# 1                                  2.519887      4.599328  ...  Zackular
# 2                                  1.213765     -0.632061  ...    Zeller
# 3                                  4.922323      6.532351  ...    Zeller
# 4                                  6.609274     -0.766400  ...    Zeller
# ..                                      ...           ...  ...       ...
# 703                                1.484075      5.444888  ...    Baxter
# 704                                3.516698     -0.213003  ...    Baxter
# 705                                3.084219     -0.147902  ...    Baxter
# 706                                3.962476      4.559395  ...    Baxter
# 707                                3.365723      3.065137  ...    Baxter
#
#      Country   Age  Gender  BMI  Total_reads  Reads_after_QC  \
# 0        FRA    58       M   24       760950          463747
# 1        USA  74       f     32       542053          381315
# 2        FRA    63       M   22       637951          410753
# 3        FRA    71       F   22       891454          490081
# 4        FRA    53       F   33       708115          472251
# ..       ...   ...     ...  ...          ...             ...
# 703      USA    63       f   25         9913            6828
# 704      USA    59       m   26         7757            4759
# 705      USA    53       m   29         5838            4046
# 706      USA    76       f   23        14010           11010
# 707      USA    66       m   24         4739            2918
#
#      used_read_count_percentage  16S_Region    Seq_platform
# 0                         60.94          V4  Illumina MiSeq
# 1                         70.35          V4  Illumina MiSeq
# 2                         64.39          V4  Illumina MiSeq
# 3                         54.98          V4  Illumina MiSeq
# 4                         66.69          V4  Illumina MiSeq
# ..                          ...         ...             ...
# 703                       68.88          V4  Illumina MiSeq
# 704                       61.35          V4  Illumina MiSeq
# 705                       69.30          V4  Illumina MiSeq
# 706                       78.59          V4  Illumina MiSeq
# 707                       61.57          V4  Illumina MiSeq
#
# [708 rows x 470 columns]

# %% [markdown]
# # Preprocessing of the dataset deleting unusefull information

# %% [markdown]
# Deleting ID and unique value that are irrelevant

# %%
df.drop(['SampleID','SubjectID'], axis=1, inplace=True)
df
# Out:
#       Lysinibacillus   Fusobacterium   Bacteroides   Prevotella  \
# 0          10.226518       -1.030177      5.755034     0.510268
# 1          -0.586193       10.592280      7.821557     1.259633
# 2           2.075989       -0.632061     10.370550     1.601531
# 3          -1.191359       -1.191359      8.804981     9.638508
# 4          -0.766400       -0.766400      5.069385     3.252982
# ..               ...             ...           ...          ...
# 703        -0.189901       -0.189901      4.986249    -0.189901
# 704        -0.213003       -0.213003      5.827251    -0.213003
# 705        -0.147902       -0.147902      5.889173     5.721395
# 706        -0.323407       -0.323407      4.330554    -0.323407
# 707        -0.180056       -0.180056      5.147820    -0.180056
#
#       Sphingomonas   Blautia   Faecalibacterium  \
# 0         6.975524  4.476509           3.372469
# 1        -0.586193  8.361916           2.004074
# 2         8.780430  6.639179           5.296641
# 3         7.414333  6.018967           8.587208
# 4        10.018656  9.904569           3.972718
# ..             ...       ...                ...
# 703      -0.189901  5.621240           4.034496
# 704      -0.213003  4.898984           3.658198
# 705      -0.147902  4.246547           4.238283
# 706      -0.323407  4.889716           1.573713
# 707      -0.180056  4.990428           2.653157
#
#       [Eubacterium]_coprostanoligenes_group   Akkermansia   Lachnoclostridium  \
# 0                                  5.962226      8.748899            4.742302
# 1                                  2.519887      4.599328            6.291446
# 2                                  1.213765     -0.632061            9.431161
# 3                                  4.922323      6.532351            4.989348
# 4                                  6.609274     -0.766400            3.305472
# ..                                      ...           ...                 ...
# 703                                1.484075      5.444888           -0.189901
# 704                                3.516698     -0.213003           -0.213003
# 705                                3.084219     -0.147902           -0.147902
# 706                                3.962476      4.559395           -0.323407
# 707                                3.365723      3.065137           -0.180056
#
#      ...     Study  Country   Age  Gender  BMI  Total_reads  Reads_after_QC  \
# 0    ...    Zeller      FRA    58       M   24       760950          463747
# 1    ...  Zackular      USA  74       f     32       542053          381315
# 2    ...    Zeller      FRA    63       M   22       637951          410753
# 3    ...    Zeller      FRA    71       F   22       891454          490081
# 4    ...    Zeller      FRA    53       F   33       708115          472251
# ..   ...       ...      ...   ...     ...  ...          ...             ...
# 703  ...    Baxter      USA    63       f   25         9913            6828
# 704  ...    Baxter      USA    59       m   26         7757            4759
# 705  ...    Baxter      USA    53       m   29         5838            4046
# 706  ...    Baxter      USA    76       f   23        14010           11010
# 707  ...    Baxter      USA    66       m   24         4739            2918
#
#      used_read_count_percentage  16S_Region    Seq_platform
# 0                         60.94          V4  Illumina MiSeq
# 1                         70.35          V4  Illumina MiSeq
# 2                         64.39          V4  Illumina MiSeq
# 3                         54.98          V4  Illumina MiSeq
# 4                         66.69          V4  Illumina MiSeq
# ..                          ...         ...             ...
# 703                       68.88          V4  Illumina MiSeq
# 704                       61.35          V4  Illumina MiSeq
# 705                       69.30          V4  Illumina MiSeq
# 706                       78.59          V4  Illumina MiSeq
# 707                       61.57          V4  Illumina MiSeq
#
# [708 rows x 468 columns]

# %%
df['16S_Region'].unique()
# Out:
# array(['V4'], dtype=object)

# %%
df.drop(['16S_Region'], axis=1, inplace=True)
df
# Out:
#       Lysinibacillus   Fusobacterium   Bacteroides   Prevotella  \
# 0          10.226518       -1.030177      5.755034     0.510268
# 1          -0.586193       10.592280      7.821557     1.259633
# 2           2.075989       -0.632061     10.370550     1.601531
# 3          -1.191359       -1.191359      8.804981     9.638508
# 4          -0.766400       -0.766400      5.069385     3.252982
# ..               ...             ...           ...          ...
# 703        -0.189901       -0.189901      4.986249    -0.189901
# 704        -0.213003       -0.213003      5.827251    -0.213003
# 705        -0.147902       -0.147902      5.889173     5.721395
# 706        -0.323407       -0.323407      4.330554    -0.323407
# 707        -0.180056       -0.180056      5.147820    -0.180056
#
#       Sphingomonas   Blautia   Faecalibacterium  \
# 0         6.975524  4.476509           3.372469
# 1        -0.586193  8.361916           2.004074
# 2         8.780430  6.639179           5.296641
# 3         7.414333  6.018967           8.587208
# 4        10.018656  9.904569           3.972718
# ..             ...       ...                ...
# 703      -0.189901  5.621240           4.034496
# 704      -0.213003  4.898984           3.658198
# 705      -0.147902  4.246547           4.238283
# 706      -0.323407  4.889716           1.573713
# 707      -0.180056  4.990428           2.653157
#
#       [Eubacterium]_coprostanoligenes_group   Akkermansia   Lachnoclostridium  \
# 0                                  5.962226      8.748899            4.742302
# 1                                  2.519887      4.599328            6.291446
# 2                                  1.213765     -0.632061            9.431161
# 3                                  4.922323      6.532351            4.989348
# 4                                  6.609274     -0.766400            3.305472
# ..                                      ...           ...                 ...
# 703                                1.484075      5.444888           -0.189901
# 704                                3.516698     -0.213003           -0.213003
# 705                                3.084219     -0.147902           -0.147902
# 706                                3.962476      4.559395           -0.323407
# 707                                3.365723      3.065137           -0.180056
#
#      ...      Diagnosis     Study  Country   Age  Gender  BMI  Total_reads  \
# 0    ...         Cancer    Zeller      FRA    58       M   24       760950
# 1    ...         Cancer  Zackular      USA  74       f     32       542053
# 2    ...         Cancer    Zeller      FRA    63       M   22       637951
# 3    ...  Large adenoma    Zeller      FRA    71       F   22       891454
# 4    ...  Small adenoma    Zeller      FRA    53       F   33       708115
# ..   ...            ...       ...      ...   ...     ...  ...          ...
# 703  ...        Adenoma    Baxter      USA    63       f   25         9913
# 704  ...         Normal    Baxter      USA    59       m   26         7757
# 705  ...        Adenoma    Baxter      USA    53       m   29         5838
# 706  ...        Adenoma    Baxter      USA    76       f   23        14010
# 707  ...        Adenoma    Baxter      USA    66       m   24         4739
#
#      Reads_after_QC  used_read_count_percentage    Seq_platform
# 0            463747                       60.94  Illumina MiSeq
# 1            381315                       70.35  Illumina MiSeq
# 2            410753                       64.39  Illumina MiSeq
# 3            490081                       54.98  Illumina MiSeq
# 4            472251                       66.69  Illumina MiSeq
# ..              ...                         ...             ...
# 703            6828                       68.88  Illumina MiSeq
# 704            4759                       61.35  Illumina MiSeq
# 705            4046                       69.30  Illumina MiSeq
# 706           11010                       78.59  Illumina MiSeq
# 707            2918                       61.57  Illumina MiSeq
#
# [708 rows x 467 columns]

# %%
df.drop(['Reads_after_QC', 'Total_reads', 'used_read_count_percentage'], axis=1, inplace=True)
df
# Out:
#       Lysinibacillus   Fusobacterium   Bacteroides   Prevotella  \
# 0          10.226518       -1.030177      5.755034     0.510268
# 1          -0.586193       10.592280      7.821557     1.259633
# 2           2.075989       -0.632061     10.370550     1.601531
# 3          -1.191359       -1.191359      8.804981     9.638508
# 4          -0.766400       -0.766400      5.069385     3.252982
# ..               ...             ...           ...          ...
# 703        -0.189901       -0.189901      4.986249    -0.189901
# 704        -0.213003       -0.213003      5.827251    -0.213003
# 705        -0.147902       -0.147902      5.889173     5.721395
# 706        -0.323407       -0.323407      4.330554    -0.323407
# 707        -0.180056       -0.180056      5.147820    -0.180056
#
#       Sphingomonas   Blautia   Faecalibacterium  \
# 0         6.975524  4.476509           3.372469
# 1        -0.586193  8.361916           2.004074
# 2         8.780430  6.639179           5.296641
# 3         7.414333  6.018967           8.587208
# 4        10.018656  9.904569           3.972718
# ..             ...       ...                ...
# 703      -0.189901  5.621240           4.034496
# 704      -0.213003  4.898984           3.658198
# 705      -0.147902  4.246547           4.238283
# 706      -0.323407  4.889716           1.573713
# 707      -0.180056  4.990428           2.653157
#
#       [Eubacterium]_coprostanoligenes_group   Akkermansia   Lachnoclostridium  \
# 0                                  5.962226      8.748899            4.742302
# 1                                  2.519887      4.599328            6.291446
# 2                                  1.213765     -0.632061            9.431161
# 3                                  4.922323      6.532351            4.989348
# 4                                  6.609274     -0.766400            3.305472
# ..                                      ...           ...                 ...
# 703                                1.484075      5.444888           -0.189901
# 704                                3.516698     -0.213003           -0.213003
# 705                                3.084219     -0.147902           -0.147902
# 706                                3.962476      4.559395           -0.323407
# 707                                3.365723      3.065137           -0.180056
#
#      ...   Pantalinema   Jonquetella   Propionibacterium      Diagnosis  \
# 0    ...     -1.030177     -1.030177           -1.030177         Cancer
# 1    ...     -0.586193     -0.586193           -0.586193         Cancer
# 2    ...     -0.632061     -0.632061           -0.632061         Cancer
# 3    ...     -1.191359     -1.191359           -1.191359  Large adenoma
# 4    ...     -0.766400     -0.766400           -0.766400  Small adenoma
# ..   ...           ...           ...                 ...            ...
# 703  ...     -0.189901     -0.189901           -0.189901        Adenoma
# 704  ...     -0.213003     -0.213003           -0.213003         Normal
# 705  ...     -0.147902     -0.147902           -0.147902        Adenoma
# 706  ...     -0.323407     -0.323407           -0.323407        Adenoma
# 707  ...     -0.180056     -0.180056           -0.180056        Adenoma
#
#         Study  Country   Age  Gender  BMI    Seq_platform
# 0      Zeller      FRA    58       M   24  Illumina MiSeq
# 1    Zackular      USA  74       f     32  Illumina MiSeq
# 2      Zeller      FRA    63       M   22  Illumina MiSeq
# 3      Zeller      FRA    71       F   22  Illumina MiSeq
# 4      Zeller      FRA    53       F   33  Illumina MiSeq
# ..        ...      ...   ...     ...  ...             ...
# 703    Baxter      USA    63       f   25  Illumina MiSeq
# 704    Baxter      USA    59       m   26  Illumina MiSeq
# 705    Baxter      USA    53       m   29  Illumina MiSeq
# 706    Baxter      USA    76       f   23  Illumina MiSeq
# 707    Baxter      USA    66       m   24  Illumina MiSeq
#
# [708 rows x 464 columns]

# %%
df['Seq_platform'].unique()
# Out:
# array(['Illumina MiSeq'], dtype=object)

# %%
df.drop(['Seq_platform'], axis=1, inplace=True)
df
# Out:
#       Lysinibacillus   Fusobacterium   Bacteroides   Prevotella  \
# 0          10.226518       -1.030177      5.755034     0.510268
# 1          -0.586193       10.592280      7.821557     1.259633
# 2           2.075989       -0.632061     10.370550     1.601531
# 3          -1.191359       -1.191359      8.804981     9.638508
# 4          -0.766400       -0.766400      5.069385     3.252982
# ..               ...             ...           ...          ...
# 703        -0.189901       -0.189901      4.986249    -0.189901
# 704        -0.213003       -0.213003      5.827251    -0.213003
# 705        -0.147902       -0.147902      5.889173     5.721395
# 706        -0.323407       -0.323407      4.330554    -0.323407
# 707        -0.180056       -0.180056      5.147820    -0.180056
#
#       Sphingomonas   Blautia   Faecalibacterium  \
# 0         6.975524  4.476509           3.372469
# 1        -0.586193  8.361916           2.004074
# 2         8.780430  6.639179           5.296641
# 3         7.414333  6.018967           8.587208
# 4        10.018656  9.904569           3.972718
# ..             ...       ...                ...
# 703      -0.189901  5.621240           4.034496
# 704      -0.213003  4.898984           3.658198
# 705      -0.147902  4.246547           4.238283
# 706      -0.323407  4.889716           1.573713
# 707      -0.180056  4.990428           2.653157
#
#       [Eubacterium]_coprostanoligenes_group   Akkermansia   Lachnoclostridium  \
# 0                                  5.962226      8.748899            4.742302
# 1                                  2.519887      4.599328            6.291446
# 2                                  1.213765     -0.632061            9.431161
# 3                                  4.922323      6.532351            4.989348
# 4                                  6.609274     -0.766400            3.305472
# ..                                      ...           ...                 ...
# 703                                1.484075      5.444888           -0.189901
# 704                                3.516698     -0.213003           -0.213003
# 705                                3.084219     -0.147902           -0.147902
# 706                                3.962476      4.559395           -0.323407
# 707                                3.365723      3.065137           -0.180056
#
#      ...   Papillibacter   Pantalinema   Jonquetella   Propionibacterium  \
# 0    ...       -1.030177     -1.030177     -1.030177           -1.030177
# 1    ...       -0.586193     -0.586193     -0.586193           -0.586193
# 2    ...       -0.632061     -0.632061     -0.632061           -0.632061
# 3    ...       -1.191359     -1.191359     -1.191359           -1.191359
# 4    ...       -0.766400     -0.766400     -0.766400           -0.766400
# ..   ...             ...           ...           ...                 ...
# 703  ...       -0.189901     -0.189901     -0.189901           -0.189901
# 704  ...       -0.213003     -0.213003     -0.213003           -0.213003
# 705  ...       -0.147902     -0.147902     -0.147902           -0.147902
# 706  ...       -0.323407     -0.323407     -0.323407           -0.323407
# 707  ...       -0.180056     -0.180056     -0.180056           -0.180056
#
#          Diagnosis     Study  Country   Age  Gender  BMI
# 0           Cancer    Zeller      FRA    58       M   24
# 1           Cancer  Zackular      USA  74       f     32
# 2           Cancer    Zeller      FRA    63       M   22
# 3    Large adenoma    Zeller      FRA    71       F   22
# 4    Small adenoma    Zeller      FRA    53       F   33
# ..             ...       ...      ...   ...     ...  ...
# 703        Adenoma    Baxter      USA    63       f   25
# 704         Normal    Baxter      USA    59       m   26
# 705        Adenoma    Baxter      USA    53       m   29
# 706        Adenoma    Baxter      USA    76       f   23
# 707        Adenoma    Baxter      USA    66       m   24
#
# [708 rows x 463 columns]

# %% [markdown]
# Mapping the different values

# %%
df['Study'].unique()
# Out:
# array(['Zeller', 'Zackular', 'Baxter'], dtype=object)

# %%
study_dict = {
    'Zeller': 0,
    'Zackular': 1,
    'Baxter': 2
}

df['Study'] = df['Study'].map(study_dict)
df['Study'].unique()
# Out:
# array([0, 1, 2])

# %%
df['Country'].unique()
# Out:
# array(['FRA', 'USA', 'CA'], dtype=object)

# %%
country_dict = {
    'FRA': 0,
    'USA': 1,
    'CA': 2
}

df['Country'] = df['Country'].map(country_dict)
df['Country'].unique()
# Out:
# array([0, 1, 2])

# %%
df['Gender'].unique(), df['Gender'].dtype
# Out:
# (array(['M', 'f\xa0\xa0', 'F', 'f', 'm', 'm\xa0\xa0'], dtype=object),
#  dtype('O'))

# %%
gender_dict = {
    'M': 0,
    'm\xa0\xa0': 0,
    'm': 0,
    'f\xa0\xa0': 1,
    'f': 1,
    'F': 1
}

df['Gender'] = df['Gender'].map(gender_dict)
df['Gender'].unique()
# Out:
# array([0, 1])

# %%
df['Gender'] = df['Gender'].fillna(-1)
df['Gender'].unique()
# Out:
# array([0, 1])

# %%
df['Age'].unique()
# Out:
# array(['58', '74\xa0\xa0', '63', '71', '53', '66', '45\xa0\xa0', '52',
#        '61', '62', '73', '50', '74', '67', '48', '60', '65', '80', '69',
#        '64', '46', '84', '76', '59', '63\xa0\xa0', '45', '47\xa0\xa0',
#        '79', '57\xa0\xa0', '56', '72', '77', '75', '54\xa0\xa0', '54',
#        '55', '65\xa0\xa0', '36', '64\xa0\xa0', '58\xa0\xa0', '49\xa0\xa0',
#        '51\xa0\xa0', '75\xa0\xa0', '78', '49', '35\xa0\xa0', '37\xa0\xa0',
#        '51', '60\xa0\xa0', '71\xa0\xa0', '81', '35', '68', '70\xa0\xa0',
#        '32', '59\xa0\xa0', '42\xa0\xa0', '44', '38', '61\xa0\xa0', '85',
#        '67\xa0\xa0', '52\xa0\xa0', '87', '62\xa0\xa0', '40', '55\xa0\xa0',
#        '57', '43\xa0\xa0', '39', '69\xa0\xa0', '47', '73\xa0\xa0', '30',
#        '72\xa0\xa0', '88\xa0\xa0', '53\xa0\xa0', '82\xa0\xa0', '42',
#        '80\xa0\xa0', '76\xa0\xa0', '56\xa0\xa0', '50\xa0\xa0', '43',
#        '68\xa0\xa0', '31', '37', '82', '29', '88', '70', '86', '41',
#        '48\xa0\xa0', '46\xa0\xa0', '89', '83', '44\xa0\xa0'], dtype=object)

# %%
df['Age'] = df['Age'].str.replace(r'(\d+)\s*\xa0*', r'\1', regex=True)
df['Age'] = df['Age'].astype('int')
df['Age'].unique()
# Out:
# array([58, 74, 63, 71, 53, 66, 45, 52, 61, 62, 73, 50, 67, 48, 60, 65, 80,
#        69, 64, 46, 84, 76, 59, 47, 79, 57, 56, 72, 77, 75, 54, 55, 36, 49,
#        51, 78, 35, 37, 81, 68, 70, 32, 42, 44, 38, 85, 87, 40, 43, 39, 30,
#        88, 82, 31, 29, 86, 41, 89, 83])

# %%
df['BMI'].unique()
# Out:
# array(['24', '32', '22', '33', '25', '20', '23', '28', '29', '26', '30',
#        '40', '34', '21', '17', '27', '37', '43', '35', '36', '31', nan,
#        '19', '38', '15', '#¡DIV/0!', '57', '41', '18', '47', '56', '46',
#        '49', '16', '50'], dtype=object)

# %%
df[df['BMI'] == '#¡DIV/0!'] = None
df['BMI'] = df['BMI'].fillna(0)
df['BMI'] = df['BMI'].astype('int')
df['BMI'].unique()
# Out:
# array([24, 32, 22, 33, 25, 20, 23, 28, 29, 26, 30, 40, 34, 21, 17, 27, 37,
#        43, 35, 36, 31,  0, 19, 38, 15, 57, 41, 18, 47, 56, 46, 49, 16, 50])

# %%
df.select_dtypes('object')
# Out:
#          Diagnosis
# 0           Cancer
# 1           Cancer
# 2           Cancer
# 3    Large adenoma
# 4    Small adenoma
# ..             ...
# 703        Adenoma
# 704         Normal
# 705        Adenoma
# 706        Adenoma
# 707        Adenoma
#
# [708 rows x 1 columns]

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# See the mutual information between the feature target and the other feature

# %%
from sklearn.feature_selection import mutual_info_classif
X = df.copy(deep=True)
y = X.pop('Diagnosis')
class_dict = {
    'Cancer': 1,
    'Adenoma': 1,
    'Large adenoma': 1,
    'Small adenoma': 1
}

y = y.map(class_dict)
y = y.fillna(0)

importances = mutual_info_classif(X, y)

mutual_info = pd.Series(importances)
mutual_info.index = X.columns
mutual_info.sort_values(ascending=False)

mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
info = mutual_info * 100
col = list(info[info > 2].index)
print('Columns:' + ','.join(col)), len(col)
# Out:
# Columns: Fusobacterium, Methanobrevibacter, Clostridia_UCG-014, Erysipelotrichaceae_UCG-003, Phascolarctobacterium, Bifidobacterium, Parvimonas, Parasutterella, Cloacibacillus, Lactococcus, Eisenbergiella, Frisingicoccus, Deinococcus, Lachnospiraceae_ND3007_group, UCG-003, Intestinimonas, Coprobacter, Family_XIII_UCG-001, Campylobacter, Defluviitaleaceae_UCG-011, [Eubacterium]_fissicatena_group, Gordonibacter,Age
# (None, 23)

# %% [markdown]
# See the distribution of the target data and set X and y

# %%
# number of raw
rows = len(df)
rows
# Out:
# 708

# %%
# Plot the distribution of the label
'Class 1:', len(df[df['Diagnosis'] != 'Normal']), 'Class 0:', len(df[df['Diagnosis'] == 'Normal'])
# Out:
# ('Class 1:', 457, 'Class 0:', 251)

# %% [markdown]
# ## Without feature Selection

# %%
X = df.copy(deep=True)
X
# Out:
#       Lysinibacillus   Fusobacterium   Bacteroides   Prevotella  \
# 0          10.226518       -1.030177      5.755034     0.510268
# 1          -0.586193       10.592280      7.821557     1.259633
# 2           2.075989       -0.632061     10.370550     1.601531
# 3          -1.191359       -1.191359      8.804981     9.638508
# 4          -0.766400       -0.766400      5.069385     3.252982
# ..               ...             ...           ...          ...
# 703        -0.189901       -0.189901      4.986249    -0.189901
# 704        -0.213003       -0.213003      5.827251    -0.213003
# 705        -0.147902       -0.147902      5.889173     5.721395
# 706        -0.323407       -0.323407      4.330554    -0.323407
# 707        -0.180056       -0.180056      5.147820    -0.180056
#
#       Sphingomonas   Blautia   Faecalibacterium  \
# 0         6.975524  4.476509           3.372469
# 1        -0.586193  8.361916           2.004074
# 2         8.780430  6.639179           5.296641
# 3         7.414333  6.018967           8.587208
# 4        10.018656  9.904569           3.972718
# ..             ...       ...                ...
# 703      -0.189901  5.621240           4.034496
# 704      -0.213003  4.898984           3.658198
# 705      -0.147902  4.246547           4.238283
# 706      -0.323407  4.889716           1.573713
# 707      -0.180056  4.990428           2.653157
#
#       [Eubacterium]_coprostanoligenes_group   Akkermansia   Lachnoclostridium  \
# 0                                  5.962226      8.748899            4.742302
# 1                                  2.519887      4.599328            6.291446
# 2                                  1.213765     -0.632061            9.431161
# 3                                  4.922323      6.532351            4.989348
# 4                                  6.609274     -0.766400            3.305472
# ..                                      ...           ...                 ...
# 703                                1.484075      5.444888           -0.189901
# 704                                3.516698     -0.213003           -0.213003
# 705                                3.084219     -0.147902           -0.147902
# 706                                3.962476      4.559395           -0.323407
# 707                                3.365723      3.065137           -0.180056
#
#      ...   Papillibacter   Pantalinema   Jonquetella   Propionibacterium  \
# 0    ...       -1.030177     -1.030177     -1.030177           -1.030177
# 1    ...       -0.586193     -0.586193     -0.586193           -0.586193
# 2    ...       -0.632061     -0.632061     -0.632061           -0.632061
# 3    ...       -1.191359     -1.191359     -1.191359           -1.191359
# 4    ...       -0.766400     -0.766400     -0.766400           -0.766400
# ..   ...             ...           ...           ...                 ...
# 703  ...       -0.189901     -0.189901     -0.189901           -0.189901
# 704  ...       -0.213003     -0.213003     -0.213003           -0.213003
# 705  ...       -0.147902     -0.147902     -0.147902           -0.147902
# 706  ...       -0.323407     -0.323407     -0.323407           -0.323407
# 707  ...       -0.180056     -0.180056     -0.180056           -0.180056
#
#          Diagnosis  Study  Country   Age  Gender  BMI
# 0           Cancer    0.0      0.0  58.0     0.0   24
# 1           Cancer    1.0      1.0  74.0     1.0   32
# 2           Cancer    0.0      0.0  63.0     0.0   22
# 3    Large adenoma    0.0      0.0  71.0     1.0   22
# 4    Small adenoma    0.0      0.0  53.0     1.0   33
# ..             ...    ...      ...   ...     ...  ...
# 703        Adenoma    2.0      1.0  63.0     1.0   25
# 704         Normal    2.0      1.0  59.0     0.0   26
# 705        Adenoma    2.0      1.0  53.0     0.0   29
# 706        Adenoma    2.0      1.0  76.0     1.0   23
# 707        Adenoma    2.0      1.0  66.0     0.0   24
#
# [708 rows x 463 columns]

# %%
y = X.pop('Diagnosis')
y
# Out:
# 0             Cancer
# 1             Cancer
# 2             Cancer
# 3      Large adenoma
# 4      Small adenoma
#            ...
# 703          Adenoma
# 704           Normal
# 705          Adenoma
# 706          Adenoma
# 707          Adenoma
# Name: Diagnosis, Length: 708, dtype: object

# %%
class_dict = {
    'Cancer': 1,
    'Adenoma': 1,
    'Large adenoma': 1,
    'Small adenoma': 1
}

y = y.map(class_dict)
y = y.fillna(0)
y
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 703    1.0
# 704    0.0
# 705    1.0
# 706    1.0
# 707    1.0
# Name: Diagnosis, Length: 708, dtype: float64

# %%
X.shape, y.shape, df.shape
# Out:
# ((708, 462), (708,), (708, 463))

# %% [markdown]
# Configure an unique alpha

# %%
# the higher the alpha, the higher is the focus on the reconstruction (loss) 
alpha = .5

# %%
percentages = [0, 10, 20, 30, 40]

blinds = [ int((len(df) / 100 * per)/2) for per in percentages]
percentages, blinds
# Out:
# ([0, 10, 20, 30, 40], [0, 35, 70, 106, 141])

# %% [markdown]
# ### With all the dataframe

# %%
n_splits = 5

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
all_mean_results = {key: {
    'macro avg precision': [],
    'macro avg recall': [],
    'macro avg f1-score': [],
    'weighted avg precision': [],
    'weighted avg recall': [],
    'weighted avg f1-score': [],
} for key in percentages }

# %%
for fold, (train_index, test_index) in tqdm(enumerate(skf.split(X, y), 1), total=n_splits):
    X_train, X_val = X[X.index.isin(train_index)], X[X.index.isin(test_index)]
    y_train, y_val = y[train_index], y[test_index]
        
    index_0 = []
    index_1 = []
    blinded = 0
    autoencoder = None
    for percentage, blind in tqdm(zip(percentages, blinds), total=len(percentages)):
        y_train_ssae = y_train.copy(deep=True)
        to_blind = blind - blinded
        
        if percentage != 0:
            index = y_train_ssae[y_train_ssae == 0].index.to_numpy()
            index = [x for x in index if x not in index_0]
            index = np.random.choice(index, size=to_blind, replace=False)
            index_0.extend(index)
            y_train_ssae[y_train_ssae.index.isin(index_0)] = None
            
            index = y_train_ssae[y_train_ssae == 1].index.tolist()
            index = [x for x in index if x not in index_1]
            index = np.random.choice(index, size=to_blind, replace=False)
            index_1.extend(index)
            y_train_ssae[y_train_ssae.index.isin(index_1)] = None
            
        
        blinded = blind
        
        autoencoder = ssae(
            input_shape=X_train.shape[1], 
            encoder_shape0=32,
            encoder_shape1=16,
            alpha=alpha
        )
        autoencoder.fit(
            X_train, (X_train, y_train_ssae),
            validation_data=(X_val, (X_val, y_val)),
            epochs=200, 
            batch_size=100, 
            verbose=0,
            callbacks=keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=20,
                verbose=0,
                restore_best_weights=True,
                mode='min',
            ),
        )
    
        encoder = models.Model(
            inputs=autoencoder.input,
            outputs=autoencoder.get_layer('layer_reduced').output
        )
        
        latent_train = encoder.predict(X_train, verbose=0)
        latent_val = encoder.predict(X_val, verbose=0)
    
        rf = RandomForestClassifier(n_estimators=100, random_state=42)
        rf.fit(latent_train, y_train)
        y_pred = rf.predict(latent_val)
    
        report = classification_report(y_val, y_pred, output_dict=True, zero_division=0)
        for metric in all_mean_results[percentage].keys():
            if 'macro' in metric:
                all_mean_results[percentage][metric].append(report['macro avg'][metric.split()[-1]])
            elif 'weighted' in metric:
                all_mean_results[percentage][metric].append(report['weighted avg'][metric.split()[-1]])
    
try:
    os.makedirs(result_path)
except:
    pass

result_df = None
for key, metrics in all_mean_results.items():
    mean_results = {metric: round(np.mean(values), 2) for metric, values in metrics.items()}
    
    res = pd.DataFrame([mean_results])
    if key == 0:
        res['Percentage reduction'] = f"SAE - {key}%"
    else:
        res['Percentage reduction'] = f"SSAE - {key}%"
    
    if result_df is None:
        result_df = res
    else:
        result_df = pd.concat([result_df, res], ignore_index=True)

result_df
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#    macro avg precision  macro avg recall  macro avg f1-score  \
# 0                 0.52              0.51                0.50
# 1                 0.52              0.52                0.50
# 2                 0.52              0.52                0.51
# 3                 0.53              0.52                0.51
# 4                 0.57              0.56                0.56
#
#    weighted avg precision  weighted avg recall  weighted avg f1-score  \
# 0                    0.56                 0.60                   0.56
# 1                    0.56                 0.60                   0.56
# 2                    0.56                 0.60                   0.57
# 3                    0.57                 0.60                   0.57
# 4                    0.60                 0.63                   0.61
#
#   Percentage reduction
# 0             SAE - 0%
# 1           SSAE - 10%
# 2           SSAE - 20%
# 3           SSAE - 30%
# 4           SSAE - 40%

# %%
result_path_fs = os.path.join(result_path, "without_FS")
try:
    os.makedirs(result_path_fs, exist_ok=True)
except:
    pass
    
result_df.to_csv(result_path_fs + f'/results_SSAE_alpha={str(alpha)}.csv')

# %%
result_path_fs = os.path.join(result_path_fs, "results_heatmap")
try:
    os.makedirs(result_path_fs, exist_ok=True)
except:
    pass
plt.figure(figsize=(7, 7))
sns.heatmap(
    result_df[result_df.columns.values[:-1]],
    cmap="RdYlGn",
    annot=True,
    fmt=".2f",
    linewidths=0.5,
    cbar_kws={"shrink": 0.8},
    yticklabels=result_df[result_df.columns.values[-1]],
)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.yticks(fontsize=10)

plt.title("Obtained Results SSAE", fontsize=16, pad=20)

plt.tight_layout()
plt.savefig(result_path_fs + f'/results_SSAE_alpha={alpha}.png')
plt.show()

# %% [markdown]
# ## With feature Selection

# %%
X = df.copy(deep=True)
X
# Out:
#       Lysinibacillus   Fusobacterium   Bacteroides   Prevotella  \
# 0          10.226518       -1.030177      5.755034     0.510268
# 1          -0.586193       10.592280      7.821557     1.259633
# 2           2.075989       -0.632061     10.370550     1.601531
# 3          -1.191359       -1.191359      8.804981     9.638508
# 4          -0.766400       -0.766400      5.069385     3.252982
# ..               ...             ...           ...          ...
# 703        -0.189901       -0.189901      4.986249    -0.189901
# 704        -0.213003       -0.213003      5.827251    -0.213003
# 705        -0.147902       -0.147902      5.889173     5.721395
# 706        -0.323407       -0.323407      4.330554    -0.323407
# 707        -0.180056       -0.180056      5.147820    -0.180056
#
#       Sphingomonas   Blautia   Faecalibacterium  \
# 0         6.975524  4.476509           3.372469
# 1        -0.586193  8.361916           2.004074
# 2         8.780430  6.639179           5.296641
# 3         7.414333  6.018967           8.587208
# 4        10.018656  9.904569           3.972718
# ..             ...       ...                ...
# 703      -0.189901  5.621240           4.034496
# 704      -0.213003  4.898984           3.658198
# 705      -0.147902  4.246547           4.238283
# 706      -0.323407  4.889716           1.573713
# 707      -0.180056  4.990428           2.653157
#
#       [Eubacterium]_coprostanoligenes_group   Akkermansia   Lachnoclostridium  \
# 0                                  5.962226      8.748899            4.742302
# 1                                  2.519887      4.599328            6.291446
# 2                                  1.213765     -0.632061            9.431161
# 3                                  4.922323      6.532351            4.989348
# 4                                  6.609274     -0.766400            3.305472
# ..                                      ...           ...                 ...
# 703                                1.484075      5.444888           -0.189901
# 704                                3.516698     -0.213003           -0.213003
# 705                                3.084219     -0.147902           -0.147902
# 706                                3.962476      4.559395           -0.323407
# 707                                3.365723      3.065137           -0.180056
#
#      ...   Papillibacter   Pantalinema   Jonquetella   Propionibacterium  \
# 0    ...       -1.030177     -1.030177     -1.030177           -1.030177
# 1    ...       -0.586193     -0.586193     -0.586193           -0.586193
# 2    ...       -0.632061     -0.632061     -0.632061           -0.632061
# 3    ...       -1.191359     -1.191359     -1.191359           -1.191359
# 4    ...       -0.766400     -0.766400     -0.766400           -0.766400
# ..   ...             ...           ...           ...                 ...
# 703  ...       -0.189901     -0.189901     -0.189901           -0.189901
# 704  ...       -0.213003     -0.213003     -0.213003           -0.213003
# 705  ...       -0.147902     -0.147902     -0.147902           -0.147902
# 706  ...       -0.323407     -0.323407     -0.323407           -0.323407
# 707  ...       -0.180056     -0.180056     -0.180056           -0.180056
#
#          Diagnosis  Study  Country   Age  Gender  BMI
# 0           Cancer    0.0      0.0  58.0     0.0   24
# 1           Cancer    1.0      1.0  74.0     1.0   32
# 2           Cancer    0.0      0.0  63.0     0.0   22
# 3    Large adenoma    0.0      0.0  71.0     1.0   22
# 4    Small adenoma    0.0      0.0  53.0     1.0   33
# ..             ...    ...      ...   ...     ...  ...
# 703        Adenoma    2.0      1.0  63.0     1.0   25
# 704         Normal    2.0      1.0  59.0     0.0   26
# 705        Adenoma    2.0      1.0  53.0     0.0   29
# 706        Adenoma    2.0      1.0  76.0     1.0   23
# 707        Adenoma    2.0      1.0  66.0     0.0   24
#
# [708 rows x 463 columns]

# %%
y = X.pop('Diagnosis')
y
# Out:
# 0             Cancer
# 1             Cancer
# 2             Cancer
# 3      Large adenoma
# 4      Small adenoma
#            ...
# 703          Adenoma
# 704           Normal
# 705          Adenoma
# 706          Adenoma
# 707          Adenoma
# Name: Diagnosis, Length: 708, dtype: object

# %% [markdown]
# We select the data that are more informative

# %%
X = X[col]
X
# Out:
#       Fusobacterium   Methanobrevibacter   Clostridia_UCG-014  \
# 0         -1.030177             7.603435             6.238279
# 1         10.592280             1.205566            -0.586193
# 2         -0.632061             0.667222            -0.632061
# 3         -1.191359            -1.191359             6.838942
# 4         -0.766400            -0.766400             0.968201
# ..              ...                  ...                  ...
# 703       -0.189901            -0.189901            -0.189901
# 704       -0.213003            -0.213003            -0.213003
# 705       -0.147902            -0.147902            -0.147902
# 706       -0.323407             4.860248             4.946168
# 707       -0.180056             2.848466            -0.180056
#
#       Erysipelotrichaceae_UCG-003   Phascolarctobacterium   Bifidobacterium  \
# 0                        1.203415                6.300228          1.129307
# 1                       -0.586193                2.207015          6.332831
# 2                       -0.632061                8.361614          2.258310
# 3                        3.443370                7.257984         -1.191359
# 4                        1.718507               -0.766400         -0.766400
# ..                            ...                     ...               ...
# 703                     -0.189901                1.484075         -0.189901
# 704                     -0.213003               -0.213003          3.107225
# 705                     -0.147902               -0.147902         -0.147902
# 706                      3.088841                4.510226          3.526741
# 707                      3.430862                1.979428          3.508823
#
#       Parvimonas   Parasutterella   Cloacibacillus   Lactococcus  ...  \
# 0       1.655400         0.436160         6.767799      1.560090  ...
# 1      -0.586193        -0.586193        -0.586193     -0.586193  ...
# 2      -0.632061         4.538423        -0.632061      0.977377  ...
# 3      -1.191359         4.573832        -1.191359      0.754551  ...
# 4       2.123972        -0.766400        -0.766400     -0.766400  ...
# ..           ...              ...              ...           ...  ...
# 703    -0.189901        -0.189901        -0.189901     -0.189901  ...
# 704    -0.213003        -0.213003        -0.213003     -0.213003  ...
# 705    -0.147902        -0.147902        -0.147902     -0.147902  ...
# 706    -0.323407        -0.323407        -0.323407     -0.323407  ...
# 707    -0.180056        -0.180056        -0.180056     -0.180056  ...
#
#       Lachnospiraceae_ND3007_group   UCG-003   Intestinimonas   Coprobacter  \
# 0                        -1.030177 -1.030177         4.766894      2.201944
# 1                         3.502580 -0.586193        -0.586193      3.182729
# 2                         0.348768 -0.632061         4.867835     -0.632061
# 3                         2.951776  5.214971         2.935775     -1.191359
# 4                        -0.766400 -0.766400        -0.766400     -0.766400
# ..                             ...       ...              ...           ...
# 703                       4.537487 -0.189901        -0.189901     -0.189901
# 704                       2.271903 -0.213003        -0.213003     -0.213003
# 705                      -0.147902 -0.147902        -0.147902      2.011582
# 706                      -0.323407 -0.323407        -0.323407     -0.323407
# 707                      -0.180056 -0.180056        -0.180056     -0.180056
#
#       Family_XIII_UCG-001   Campylobacter   Defluviitaleaceae_UCG-011  \
# 0                1.203415       -1.030177                    2.075903
# 1               -0.586193       -0.586193                   -0.586193
# 2               -0.632061       -0.632061                   -0.632061
# 3                2.930385       -1.191359                    2.622684
# 4                2.504436       -0.766400                   -0.766400
# ..                    ...             ...                         ...
# 703             -0.189901       -0.189901                    0.320924
# 704             -0.213003       -0.213003                   -0.213003
# 705             -0.147902       -0.147902                   -0.147902
# 706             -0.323407       -0.323407                    0.657423
# 707             -0.180056       -0.180056                   -0.180056
#
#       [Eubacterium]_fissicatena_group   Gordonibacter   Age
# 0                           -1.030177       -1.030177  58.0
# 1                           -0.586193       -0.586193  74.0
# 2                            2.638774       -0.632061  63.0
# 3                           -1.191359       -1.191359  71.0
# 4                            2.979175       -0.766400  53.0
# ..                                ...             ...   ...
# 703                         -0.189901       -0.189901  63.0
# 704                         -0.213003       -0.213003  59.0
# 705                         -0.147902       -0.147902  53.0
# 706                         -0.323407       -0.323407  76.0
# 707                         -0.180056       -0.180056  66.0
#
# [708 rows x 23 columns]

# %%
class_dict = {
    'Cancer': 1,
    'Adenoma': 1,
    'Large adenoma': 1,
    'Small adenoma': 1
}

y = y.map(class_dict)
y = y.fillna(0)
y
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 703    1.0
# 704    0.0
# 705    1.0
# 706    1.0
# 707    1.0
# Name: Diagnosis, Length: 708, dtype: float64

# %%
X.shape, y.shape, df.shape
# Out:
# ((708, 23), (708,), (708, 463))

# %% [markdown]
# ### With all the dataframe

# %%
all_mean_results = {key: {
    'macro avg precision': [],
    'macro avg recall': [],
    'macro avg f1-score': [],
    'weighted avg precision': [],
    'weighted avg recall': [],
    'weighted avg f1-score': [],
} for key in percentages }

# %%
for fold, (train_index, test_index) in tqdm(enumerate(skf.split(X, y), 1), total=n_splits):
    X_train, X_val = X[X.index.isin(train_index)], X[X.index.isin(test_index)]
    y_train, y_val = y[train_index], y[test_index]
        
    index_0 = []
    index_1 = []
    blinded = 0
    for percentage, blind in tqdm(zip(percentages, blinds), total=len(percentages)):
        y_train_ssae = y_train.copy(deep=True)
        to_blind = blind - blinded
        autoencoder = None
        if percentage != 0:
            index = y_train_ssae[y_train_ssae == 0].index.to_numpy()
            index = [x for x in index if x not in index_0]
            index = np.random.choice(index, size=to_blind, replace=False)
            index_0.extend(index)
            y_train_ssae[y_train_ssae.index.isin(index_0)] = None
            
            index = y_train_ssae[y_train_ssae == 1].index.tolist()
            index = [x for x in index if x not in index_1]
            index = np.random.choice(index, size=to_blind, replace=False)
            index_1.extend(index)
            y_train_ssae[y_train_ssae.index.isin(index_1)] = None
            
        blinded = blind
        
        autoencoder = ssae(
            input_shape=X_train.shape[1], 
            encoder_shape0=32,
            encoder_shape1=16,
            alpha=alpha
        )
        autoencoder.fit(
            X_train, (X_train, y_train_ssae),
            validation_data=(X_val, (X_val, y_val)),
            epochs=200, 
            batch_size=100, 
            verbose=0,
            callbacks=keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=20,
                verbose=0,
                restore_best_weights=True,
                mode='min',
            ),
        )
    
        encoder = models.Model(
            inputs=autoencoder.input,
            outputs=autoencoder.get_layer('layer_reduced').output
        )
        
        latent_train = encoder.predict(X_train, verbose=0)
        latent_val = encoder.predict(X_val, verbose=0)
    
        rf = RandomForestClassifier(n_estimators=100, random_state=42)
        rf.fit(latent_train, y_train)
        y_pred = rf.predict(latent_val)
    
        report = classification_report(y_val, y_pred, output_dict=True, zero_division=0)
        for metric in all_mean_results[percentage].keys():
            if 'macro' in metric:
                all_mean_results[percentage][metric].append(report['macro avg'][metric.split()[-1]])
            elif 'weighted' in metric:
                all_mean_results[percentage][metric].append(report['weighted avg'][metric.split()[-1]])
    
try:
    os.makedirs(result_path)
except:
    pass

result_df = None
for key, metrics in all_mean_results.items():
    mean_results = {metric: round(np.mean(values), 2) for metric, values in metrics.items()}
    
    res = pd.DataFrame([mean_results])
    if key == 0:
        res['Percentage reduction'] = f"SAE - {key}%"
    else:
        res['Percentage reduction'] = f"SSAE - {key}%"
    
    if result_df is None:
        result_df = res
    else:
        result_df = pd.concat([result_df, res], ignore_index=True)

result_df
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#    macro avg precision  macro avg recall  macro avg f1-score  \
# 0                 0.56              0.54                0.53
# 1                 0.56              0.55                0.54
# 2                 0.52              0.52                0.51
# 3                 0.56              0.54                0.53
# 4                 0.58              0.55                0.54
#
#    weighted avg precision  weighted avg recall  weighted avg f1-score  \
# 0                    0.59                 0.62                   0.59
# 1                    0.59                 0.62                   0.60
# 2                    0.56                 0.60                   0.57
# 3                    0.59                 0.63                   0.59
# 4                    0.60                 0.63                   0.60
#
#   Percentage reduction
# 0             SAE - 0%
# 1           SSAE - 10%
# 2           SSAE - 20%
# 3           SSAE - 30%
# 4           SSAE - 40%

# %%
result_path_fs = os.path.join(result_path, "with_FS")

try:
    os.makedirs(result_path_fs)
except:
    pass
    
result_df.to_csv(result_path_fs + f'/results_SSAE_alpha={str(alpha)}_with_{len(col)}_feature.csv')

# %%
result_path_fs = os.path.join(result_path_fs, "results_heatmap")
try:
    os.makedirs(result_path_fs, exist_ok=True)
except:
    pass
plt.figure(figsize=(7, 7))
sns.heatmap(
    result_df[result_df.columns.values[:-1]],
    cmap="RdYlGn",
    annot=True,
    fmt=".2f",
    linewidths=0.5,
    cbar_kws={"shrink": 0.8},
    yticklabels=result_df[result_df.columns.values[-1]],
)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.yticks(fontsize=10)

plt.title("Obtained Results SSAE", fontsize=16, pad=20)

plt.tight_layout()
plt.savefig(result_path_fs + f'/results_SSAE_alpha={alpha}.png')
plt.show()
